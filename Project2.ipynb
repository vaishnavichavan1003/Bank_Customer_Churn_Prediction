# %% [markdown]
# # Title : Bank Churn Prediction Data

# %% [markdown]
# ### Import Basic Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Note: in above query we have import libraries pandas,numpy,matplotlib, and seaborn

# %% [markdown]
# ### Import Dataset

# %%
df=pd.read_csv("bankdata.csv")

# %% [markdown]
# ### Display data

# %%
df
# Out:
#             id  CustomerId         Surname  CreditScore Geography  Gender  \
# 0            0    15674932  Okwudilichukwu          668    France    Male
# 1            1    15749177   Okwudiliolisa          627    France    Male
# 2            2    15694510           Hsueh          678    France    Male
# 3            3    15741417             Kao          581    France    Male
# 4            4    15766172       Chiemenam          716     Spain    Male
# ...        ...         ...             ...          ...       ...     ...
# 165029  165029    15667085            Meng          667     Spain  Female
# 165030  165030    15665521       Okechukwu          792    France    Male
# 165031  165031    15664752            Hsia          565    France    Male
# 165032  165032    15689614          Hsiung          554     Spain  Female
# 165033  165033    15732798         Ulyanov          850    France    Male
#
#          Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       33.0       3       0.00              2        1.0             0.0
# 1       33.0       1       0.00              2        1.0             1.0
# 2       40.0      10       0.00              2        1.0             0.0
# 3       34.0       2  148882.54              1        1.0             1.0
# 4       33.0       5       0.00              2        1.0             1.0
# ...      ...     ...        ...            ...        ...             ...
# 165029  33.0       2       0.00              1        1.0             1.0
# 165030  35.0       3       0.00              1        0.0             0.0
# 165031  31.0       5       0.00              1        1.0             1.0
# 165032  30.0       7  161533.00              1        0.0             1.0
# 165033  31.0       1       0.00              1        1.0             0.0
#
#         EstimatedSalary  Exited
# 0             181449.97       0
# 1              49503.50       0
# 2             184866.69       0
# 3              84560.88       0
# 4              15068.83       0
# ...                 ...     ...
# 165029        131834.75       0
# 165030        131834.45       0
# 165031        127429.56       0
# 165032         71173.03       0
# 165033         61581.79       1
#
# [165034 rows x 14 columns]

# %%
# Note : here we can overall data there are 14 columns and 1 lakh 65 thousand 34 rows

# %%
# top 5 records display
df.head()
# Out:
#    id  CustomerId         Surname  CreditScore Geography Gender   Age  Tenure  \
# 0   0    15674932  Okwudilichukwu          668    France   Male  33.0       3
# 1   1    15749177   Okwudiliolisa          627    France   Male  33.0       1
# 2   2    15694510           Hsueh          678    France   Male  40.0      10
# 3   3    15741417             Kao          581    France   Male  34.0       2
# 4   4    15766172       Chiemenam          716     Spain   Male  33.0       5
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              2        1.0             0.0        181449.97
# 1       0.00              2        1.0             1.0         49503.50
# 2       0.00              2        1.0             0.0        184866.69
# 3  148882.54              1        1.0             1.0         84560.88
# 4       0.00              2        1.0             1.0         15068.83
#
#    Exited
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# bottom 5 records display
df.tail()
# Out:
#             id  CustomerId    Surname  CreditScore Geography  Gender   Age  \
# 165029  165029    15667085       Meng          667     Spain  Female  33.0
# 165030  165030    15665521  Okechukwu          792    France    Male  35.0
# 165031  165031    15664752       Hsia          565    France    Male  31.0
# 165032  165032    15689614     Hsiung          554     Spain  Female  30.0
# 165033  165033    15732798    Ulyanov          850    France    Male  31.0
#
#         Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 165029       2       0.0              1        1.0             1.0
# 165030       3       0.0              1        0.0             0.0
# 165031       5       0.0              1        1.0             1.0
# 165032       7  161533.0              1        0.0             1.0
# 165033       1       0.0              1        1.0             0.0
#
#         EstimatedSalary  Exited
# 165029        131834.75       0
# 165030        131834.45       0
# 165031        127429.56       0
# 165032         71173.03       0
# 165033         61581.79       1

# %%
# shape of data
df.shape
# Out:
# (165034, 14)

# %%
# size of data
df.size
# Out:
# 2310476

# %%
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %% [markdown]
# ### Check data types all columns

# %%
df.dtypes
# Out:
# id                   int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                float64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard          float64
# IsActiveMember     float64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# ### drop unnecessary colmns

# %%
df.drop(["id","CustomerId","Surname"],axis=1,inplace=True)

# %%
# create a shallow copy of data
df1=df.copy()

# %%
# check null values present in data
df1.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ### Check overall information of data and also statistical summary

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165034 entries, 0 to 165033
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   CreditScore      165034 non-null  int64
#  1   Geography        165034 non-null  object
#  2   Gender           165034 non-null  object
#  3   Age              165034 non-null  float64
#  4   Tenure           165034 non-null  int64
#  5   Balance          165034 non-null  float64
#  6   NumOfProducts    165034 non-null  int64
#  7   HasCrCard        165034 non-null  float64
#  8   IsActiveMember   165034 non-null  float64
#  9   EstimatedSalary  165034 non-null  float64
#  10  Exited           165034 non-null  int64
# dtypes: float64(5), int64(4), object(2)
# memory usage: 13.9+ MB

# %%
# Note :  Here we can see column wise datatypes,Null value is present in column, how many entries of this data
# also how many rows and columns are present

# %%
df1.describe().T
# Out:
#                     count           mean           std     min       25%  \
# CreditScore      165034.0     656.454373     80.103340  350.00    597.00
# Age              165034.0      38.125888      8.867205   18.00     32.00
# Tenure           165034.0       5.020353      2.806159    0.00      3.00
# Balance          165034.0   55478.086689  62817.663278    0.00      0.00
# NumOfProducts    165034.0       1.554455      0.547154    1.00      1.00
# HasCrCard        165034.0       0.753954      0.430707    0.00      1.00
# IsActiveMember   165034.0       0.497770      0.499997    0.00      0.00
# EstimatedSalary  165034.0  112574.822734  50292.865585   11.58  74637.57
# Exited           165034.0       0.211599      0.408443    0.00      0.00
#
#                       50%          75%        max
# CreditScore         659.0     710.0000     850.00
# Age                  37.0      42.0000      92.00
# Tenure                5.0       7.0000      10.00
# Balance               0.0  119939.5175  250898.09
# NumOfProducts         2.0       2.0000       4.00
# HasCrCard             1.0       1.0000       1.00
# IsActiveMember        0.0       1.0000       1.00
# EstimatedSalary  117948.0  155152.4675  199992.48
# Exited                0.0       0.0000       1.00

# %%
# check the unique values of Gender
df1["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df1["Gender"].value_counts(normalize=True)*100
# Out:
# Gender
# Male      56.442915
# Female    43.557085
# Name: proportion, dtype: float64

# %%
# Note : here 56% of male are there and 43% of female

# %%
plt.pie(df1["Gender"].value_counts(normalize=True)*100,labels=["Male","Female"],autopct='%1.1f%%')
plt.title("Pie for Gender column")
plt.show()

# %%
df1["Geography"].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df1["Geography"].value_counts(normalize=True)*100
# Out:
# Geography
# France     57.088236
# Spain      21.942751
# Germany    20.969012
# Name: proportion, dtype: float64

# %%
plt.pie(df1["Geography"].value_counts(normalize=True)*100,labels=['France', 'Spain', 'Germany'],autopct='%1.1f%%')
plt.title("Pie for Geography column")
plt.show()

# %% [markdown]
# ### Convert categorical data into numerical using LabelEncoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df1.dtypes
# Out:
# CreditScore          int64
# Geography           object
# Gender              object
# Age                float64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard          float64
# IsActiveMember     float64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
le=LabelEncoder()

# %%
df1["Geography"]=le.fit_transform(df1["Geography"])
df1["Gender"]=le.fit_transform(df1["Gender"])

# %%
df1.head(2)
# Out:
#    CreditScore  Geography  Gender   Age  Tenure  Balance  NumOfProducts  \
# 0          668          0       1  33.0       3      0.0              2
# 1          627          0       1  33.0       1      0.0              2
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0        1.0             0.0        181449.97       0
# 1        1.0             1.0         49503.50       0

# %% [markdown]
# ### Check Outliers

# %%
plt.figure(figsize=(17,9))
sns.boxplot(df1)
plt.show()

# %%
# Note : in the dataset there is no outliers present

# %% [markdown]
# ### Check Skewness

# %%
df1.skew()
# Out:
# CreditScore       -0.059291
# Geography          0.725460
# Gender            -0.259886
# Age                0.968063
# Tenure             0.006490
# Balance            0.382020
# NumOfProducts      0.368278
# HasCrCard         -1.179255
# IsActiveMember     0.008920
# EstimatedSalary   -0.309022
# Exited             1.412215
# dtype: float64

# %%
# here the skewness is negligible

# %% [markdown]
# ### Split data in x and y

# %%
x=df1.drop(["Exited"],axis=1)

# %%
y=df1["Exited"]

# %% [markdown]
# ### Scaling

# %%
#import a zscore scaling which is similar to standard scaling
from scipy.stats import zscore

# %%
#apply the scaling 
x_sc=x.apply(zscore)

# %%
x_sc.head()
# Out:
#    CreditScore  Geography    Gender       Age    Tenure   Balance  \
# 0     0.144135  -0.794229  0.878465 -0.578074 -0.719973 -0.883163
# 1    -0.367706  -0.794229  0.878465 -0.578074 -1.432694 -0.883163
# 2     0.268974  -0.794229  0.878465  0.211354  1.774548 -0.883163
# 3    -0.941966  -0.794229  0.878465 -0.465299 -1.076334  1.486918
# 4     0.743362   1.655035  0.878465 -0.578074 -0.007253 -0.883163
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0       0.814298   0.571263        -0.99555         1.369486
# 1       0.814298   0.571263         1.00447        -1.254085
# 2       0.814298   0.571263        -0.99555         1.437422
# 3      -1.013348   0.571263         1.00447        -0.557018
# 4       0.814298   0.571263         1.00447        -1.938770

# %% [markdown]
# ### Split data in train and test

# %%
# import model for spliting data
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_sc,y,test_size=0.3,random_state=1)

# %% [markdown]
# ## Check all models training and testing score

# %%
'''
1. Logistic Regression
2. Knn Classifier
3. Decision Tree Classifier
4. Bagging Classifier
5. Ada Boost Classifier
6. Random Forest Classifier
7. Gradient Bossting Classifier
'''
# Out:
# '\n1. Logistic Regression\n2. Knn Classifier\n3. Decision Tree Classifier\n4. Bagging Classifier\n5. Ada Boost Classifier\n6. Random Forest Classifier\n7. Gradient Bossting Classifier\n'

# %% [markdown]
# ### 1. Logistic Regression

# %%
# import Logistic Regression
from sklearn.linear_model import LogisticRegression

# %%
# creating object for logistic regression
lor=LogisticRegression()

# %%
lor.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
# training score check
lor.score(x_train,y_train)*100
# Out:
# 82.57143599110134

# %%
# testing score check
lor.score(x_test,y_test)*100
# Out:
# 82.69475470097554

# %%
# Training Score(82.57) - Testing Score(82.67) =  -0.12

# %% [markdown]
# #### Find Precision score, Recall Score, accuracy of model and also confusion matrix

# %%
from sklearn.metrics import precision_score,recall_score,accuracy_score,confusion_matrix

# %%
y_true,y_pred=y_test,lor.predict(x_test)

# %%
# find precision score
precision_score(y_true,y_pred)*100
# Out:
# 67.92068198665679

# %%
# find recall score
recall_score(y_true,y_pred)*100
# Out:
# 34.89811464482956

# %%
# find accuracy score
accuracy_score(y_true,y_pred)*100
# Out:
# 82.69475470097554

# %%
# plot the confusion matrix
sns.heatmap(confusion_matrix(y_true,y_pred),annot=True,fmt='d')
plt.title("confusion matrix")
plt.xlabel("actual")
plt.ylabel("predicted")
plt.show()

# %% [markdown]
# ### 2. KNN classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(x_train,y_train)*100
# Out:
# 88.51310994347446

# %%
knn.score(x_test,y_test)*100
# Out:
# 84.65391529155137

# %%
# Training Score(88.51) - Testing Score(84.65) =  3.86

# %% [markdown]
# #### Find Precision score, Recall Score, accuracy of model and also confusion matrix

# %%
y_true,y_pred=y_test,knn.predict(x_test)

# %%
# precision Score
precision_score(y_true,y_pred)*100
# Out:
# 67.32696897374701

# %%
# recall Score
recall_score(y_true,y_pred)*100
# Out:
# 53.72310036183584

# %%
# accuracy score
accuracy_score(y_true,y_pred)*100
# Out:
# 84.65391529155137

# %%
# plot the confusion matrix
sns.heatmap(confusion_matrix(y_true,y_pred),annot=True,fmt='d')
plt.title("confusion matrix")
plt.xlabel("actual")
plt.ylabel("predicted")
plt.show()

# %% [markdown]
# ### 3. Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc =  DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc.score(x_train,y_train)*100
# Out:
# 99.97489677380263

# %%
dtc.score(x_test,y_test)*100
# Out:
# 79.89335703177072

# %%
# Training Score(99.97) - Testing Score(79.87) =  20.1

# %% [markdown]
# #### Find Precision score, Recall Score, accuracy of model and also confusion matrix

# %%
y_true,y_pred=y_test,dtc.predict(x_test)

# %%
precision_score(y_true,y_pred)*100
# Out:
# 52.502058366114724

# %%
recall_score(y_true,y_pred)*100
# Out:
# 54.64673395543706

# %%
accuracy_score(y_true,y_pred)*100
# Out:
# 79.89335703177072

# %%
# plot the confusion matrix
sns.heatmap(confusion_matrix(y_true,y_pred),annot=True,fmt='d')
plt.title("confusion matrix")
plt.xlabel("actual")
plt.ylabel("predicted")
plt.show()

# %% [markdown]
# ### 4.Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bgc=BaggingClassifier()

# %%
bgc.fit(x_train,y_train)
# Out:
# BaggingClassifier()

# %%
bgc.score(x_train,y_train)*100
# Out:
# 98.5396847381041

# %%
bgc.score(x_test,y_test)*100
# Out:
# 84.74076467855627

# %%
# Training Score(98.45) - Testing Score(84.90) =  13.55

# %% [markdown]
# #### Find Precision score, Recall Score, accuracy of model and also confusion matrix

# %%
y_true,y_pred=y_test,bgc.predict(x_test)

# %%
precision_score(y_true,y_pred)*100
# Out:
# 69.12891081396857

# %%
recall_score(y_true,y_pred)*100
# Out:
# 50.70462768996382

# %%
accuracy_score(y_true,y_pred)*100
# Out:
# 84.74076467855627

# %%
# plot the confusion matrix
sns.heatmap(confusion_matrix(y_true,y_pred),annot=True,fmt='d')
plt.title("confusion matrix")
plt.xlabel("actual")
plt.ylabel("predicted")
plt.show()

# %% [markdown]
# ### 5. Ada Boost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada=AdaBoostClassifier()

# %%
ada.fit(x_train,y_train)
# Out:
# C:\Users\Vaishnavi Chavan\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier()

# %%
ada.score(x_train,y_train)*100
# Out:
# 86.06078443253725

# %%
ada.score(x_test,y_test)*100
# Out:
# 86.01926844539597

# %%
# Training Score(86.06) - Testing Score(86.01) =  0.05

# %% [markdown]
# #### Find Precision score, Recall Score, accuracy of model and also confusion matrix

# %%
y_true,y_pred=y_test,ada.predict(x_test)

# %%
precision_score(y_true,y_pred)*100
# Out:
# 73.95610278372591

# %%
recall_score(y_true,y_pred)*100
# Out:
# 52.61854884783851

# %%
accuracy_score(y_true,y_pred)*100
# Out:
# 86.01926844539597

# %%
# plot the confusion matrix
sns.heatmap(confusion_matrix(y_true,y_pred),annot=True,fmt='d')
plt.title("confusion matrix")
plt.xlabel("actual")
plt.ylabel("predicted")
plt.show()

# %% [markdown]
# ### 6. Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rfc.score(x_train,y_train)*100
# Out:
# 99.97229988833392

# %%
rfc.score(x_test,y_test)*100
# Out:
# 85.79507584173214

# %%
# Training Score(99.97) - Testing Score(85.74) =  14.23

# %% [markdown]
# #### Find Precision score, Recall Score, accuracy of model and also confusion matrix

# %%
y_true,y_pred=y_test,rfc.predict(x_test)

# %%
precision_score(y_true,y_pred)*100
# Out:
# 72.14349546789225

# %%
recall_score(y_true,y_pred)*100
# Out:
# 53.80879832412874

# %%
accuracy_score(y_true,y_pred)*100
# Out:
# 85.79507584173214

# %%
# plot the confusion matrix
sns.heatmap(confusion_matrix(y_true,y_pred),annot=True,fmt='d')
plt.title("confusion matrix")
plt.xlabel("actual")
plt.ylabel("predicted")
plt.show()

# %% [markdown]
# ### 7. Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc=GradientBoostingClassifier()

# %%
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
gbc.score(x_train,y_train)*100
# Out:
# 86.48667364940314

# %%
gbc.score(x_test,y_test)*100
# Out:
# 86.43331784855891

# %%
# Training Score(86.48) - Testing Score(86.43) =  0.05

# %% [markdown]
# #### Find Precision score, Recall Score, accuracy of model and also confusion matrix

# %%
y_true,y_pred=y_test,gbc.predict(x_test)

# %%
precision_score(y_true,y_pred)*100
# Out:
# 75.12279304393999

# %%
recall_score(y_true,y_pred)*100
# Out:
# 53.88497429061131

# %%
accuracy_score(y_true,y_pred)*100
# Out:
# 86.43331784855891

# %%
# plot the confusion matrix
sns.heatmap(confusion_matrix(y_true,y_pred),annot=True,fmt='d')
plt.title("confusion matrix")
plt.xlabel("actual")
plt.ylabel("predicted")
plt.show()

# %% [markdown]
# ## Model Evaluation

# %%
model_evaluation=pd.DataFrame(data={
    "Algorithm ": ["Logistic Regression","k-Nearest Neighbors Classsifier","Decision Tree Classifier","Bagging","Ada Boost Classifier","Random Forest Classifier","Gradient Boost classifier"],
    "Trainig Score" :[82.57,88.51,99.97,98.45,86.06,99.97,86.84],
    "Testing Score" : [82.69,84.65,79.87,84.90,86.01,85.74,86.43],
    "Error" : [-0.12,3.86,20.1,13.55,0.05,14.23,0.05],
    "Accuracy" : [82.69,84.65,79.87,84.90,86.01,85.74,86.43]
})

# %%
model_evaluation
# Out:
#                         Algorithm   Trainig Score  Testing Score  Error  \
# 0              Logistic Regression          82.57          82.69  -0.12
# 1  k-Nearest Neighbors Classsifier          88.51          84.65   3.86
# 2         Decision Tree Classifier          99.97          79.87  20.10
# 3                          Bagging          98.45          84.90  13.55
# 4             Ada Boost Classifier          86.06          86.01   0.05
# 5         Random Forest Classifier          99.97          85.74  14.23
# 6        Gradient Boost classifier          86.84          86.43   0.05
#
#    Accuracy
# 0     82.69
# 1     84.65
# 2     79.87
# 3     84.90
# 4     86.01
# 5     85.74
# 6     86.43

# %% [markdown]
# ## Conclusion

# %%
'''
Using the algorithm such as Logistic Regression, k-Nearest Neighbors Classsifier, Decision Tree 
Classifier, Bagging, Ada Boost Classifier,Random Forest Classifier, Gradient Boost classifier. 
compare all the alogrithms choose the gradient boosting classifier it achieved high testing accuracy 
with minimal difference from the training accuracy, indicating robust performance without overfitting.
The accuracy of the gradient boost classifier is 86.43%. The difference of training score (86.84) 
and testing score(86.43) is 0.05.
'''
# Out:
# '\nUsing the algorithm such as Logistic Regression, k-Nearest Neighbors Classsifier, Decision Tree \nClassifier, Bagging, Ada Boost Classifier,Random Forest Classifier, Gradient Boost classifier. \ncompare all the alogrithms choose the gradient boosting classifier it achieved high testing accuracy \nwith minimal difference from the training accuracy, indicating robust performance without overfitting.\nThe accuracy of the gradient boost classifier is 86.43%. The difference of training score (86.84) \nand testing score(86.43) is 0.05.\n'
